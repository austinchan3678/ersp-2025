# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.special import j0
from kan.KAN import KAN
from kan.qsp_activation import expectation_value

# -------------------------------
# Device setup
# -------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# -------------------------------
# Edge-warped sampling function
# -------------------------------
def warp_edges(L):
    t = np.linspace(0, np.pi, L)
    x_dense = np.cos(t)
    return np.sort(x_dense).reshape(-1, 1)

# -------------------------------
# Weighted cost function
# -------------------------------
def weighted_cost_fn(params, x, y_norm, depth, lambda_reg=1e-3):
    qsp_params = params[:2 * depth + 1]
    alphas = params[2 * depth + 1:]

    preds, weights = [], []
    for i in range(len(x)):
        theta = x[i][0]
        val = expectation_value(qsp_params, theta, depth=depth)
        preds.append(alphas[i] * val)
        weights.append(1 + 10 * (abs(theta) ** 2))

    preds = np.array(preds)
    weights = np.array(weights)
    mse = np.mean(weights * (y_norm.flatten() - preds) ** 2)
    alpha_penalty = lambda_reg * np.mean(np.square(alphas))
    return mse + alpha_penalty

# -------------------------------
# Train and optionally prune
# -------------------------------
def train_and_prune(x, y, width, qsp_depth=35, steps=1000, pruning_threshold=0.05):
    model = KAN(width, qsp_depth=qsp_depth, device=device)

    x_tensor = torch.tensor(x, dtype=torch.float32, device=device)
    y_tensor = torch.tensor(y, dtype=torch.float32, device=device)

    y_max = np.max(np.abs(y))
    y_norm = y / y_max

    init_qsp_params = np.linspace(0, np.pi, model.num_qsp_params)
    init_alphas = np.random.uniform(0.5, 1.5, x.shape[0])
    init_params = np.concatenate([init_qsp_params, init_alphas])

    result = model.fit_qsp_with_alphas(
        x_tensor, y_tensor,
        maxiter=steps,
        cost_fn=lambda p: weighted_cost_fn(p, x, y_norm, depth=qsp_depth),
        init_params=init_params
    )
    qsp_params = result.x[:model.num_qsp_params]
    alphas = result.x[model.num_qsp_params:]

    # -------------------------------
    # Pruning: keep samples with significant alpha × QSP(theta)
    # -------------------------------
    importance = np.abs([
        alphas[i] * expectation_value(qsp_params, x[i][0], depth=qsp_depth)
        for i in range(len(x))
    ])
    keep_indices = np.where(importance > pruning_threshold)[0]
    print(f"Pruning: keeping {len(keep_indices)} / {len(x)} points")

    # Retrain if pruning reduced the set
    if len(keep_indices) < len(x):
        x_pruned = x[keep_indices]
        y_pruned = y[keep_indices]
        model = KAN(width, qsp_depth=qsp_depth, device=device)
        x_tensor = torch.tensor(x_pruned, dtype=torch.float32, device=device)
        y_tensor = torch.tensor(y_pruned, dtype=torch.float32, device=device)

        result = model.fit_qsp_with_alphas(
            x_tensor, y_tensor,
            maxiter=steps,
            cost_fn=lambda p: weighted_cost_fn(p, x_pruned, y_pruned / y_max, qsp_depth),
            init_params=np.concatenate([qsp_params, alphas[keep_indices]])
        )
        qsp_params = result.x[:model.num_qsp_params]
        alphas = result.x[model.num_qsp_params:]

        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x_pruned, y_pruned

    else:
        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x, y

# -------------------------------
# Main execution
# -------------------------------
x_full = np.linspace(-1.2, 1.2, 200).reshape(-1, 1)
y_full = j0(20 * x_full)

model, preds_full, x_used, y_used = train_and_prune(
    x_full, y_full, width=[10, 10, 1], steps=1000, pruning_threshold=0.05
)

# -------------------------------
# Plotting
# -------------------------------
plt.figure(figsize=(10, 6))
plt.plot(x_full, y_full, label="Target: J₀(20x)", linewidth=2)
plt.plot(x_used, preds_full, '--', label="KAN (after pruning)", linewidth=2)
plt.title("KAN QSP Bessel Approximation with Pruning")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
# Pruning: keeping 134 / 200 points

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.special import j0
from kan.KAN import KAN
from kan.qsp_activation import expectation_value

# -------------------------------
# Device setup
# -------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# -------------------------------
# Edge-warped sampling function
# -------------------------------
def warp_edges(L):
    t = np.linspace(0, np.pi, L)
    x_dense = np.cos(t)
    return np.sort(x_dense).reshape(-1, 1)

# -------------------------------
# Weighted cost function
# -------------------------------
def weighted_cost_fn(params, x, y_norm, depth, lambda_reg=1e-3):
    qsp_params = params[:2 * depth + 1]
    alphas = params[2 * depth + 1:]

    preds, weights = [], []
    for i in range(len(x)):
        theta = x[i][0]
        val = expectation_value(qsp_params, theta, depth=depth)
        preds.append(alphas[i] * val)
        weights.append(1 + 10 * (abs(theta) ** 2))

    preds = np.array(preds)
    weights = np.array(weights)
    mse = np.mean(weights * (y_norm.flatten() - preds) ** 2)
    alpha_penalty = lambda_reg * np.mean(np.square(alphas))
    return mse + alpha_penalty

# -------------------------------
# Train and optionally prune
# -------------------------------
def train_and_prune(x, y, width, qsp_depth=15, steps=1000, pruning_threshold=0.05):
    model = KAN(width, qsp_depth=qsp_depth, device=device)

    x_tensor = torch.tensor(x, dtype=torch.float32, device=device)
    y_tensor = torch.tensor(y, dtype=torch.float32, device=device)

    y_max = np.max(np.abs(y))
    y_norm = y / y_max

    init_qsp_params = np.linspace(0, np.pi, model.num_qsp_params)
    init_alphas = np.random.uniform(0.5, 1.5, x.shape[0])
    init_params = np.concatenate([init_qsp_params, init_alphas])

    result = model.fit_qsp_with_alphas(
        x_tensor, y_tensor,
        maxiter=steps,
        cost_fn=lambda p: weighted_cost_fn(p, x, y_norm, depth=qsp_depth),
        init_params=init_params
    )
    qsp_params = result.x[:model.num_qsp_params]
    alphas = result.x[model.num_qsp_params:]

    # -------------------------------
    # Pruning: keep samples with significant alpha × QSP(theta)
    # -------------------------------
    importance = np.abs([
        alphas[i] * expectation_value(qsp_params, x[i][0], depth=qsp_depth)
        for i in range(len(x))
    ])
    keep_indices = np.where(importance > pruning_threshold)[0]
    print(f"Pruning: keeping {len(keep_indices)} / {len(x)} points")

    # Retrain if pruning reduced the set
    if len(keep_indices) < len(x):
        x_pruned = x[keep_indices]
        y_pruned = y[keep_indices]
        model = KAN(width, qsp_depth=qsp_depth, device=device)
        x_tensor = torch.tensor(x_pruned, dtype=torch.float32, device=device)
        y_tensor = torch.tensor(y_pruned, dtype=torch.float32, device=device)

        result = model.fit_qsp_with_alphas(
            x_tensor, y_tensor,
            maxiter=steps,
            cost_fn=lambda p: weighted_cost_fn(p, x_pruned, y_pruned / y_max, qsp_depth),
            init_params=np.concatenate([qsp_params, alphas[keep_indices]])
        )
        qsp_params = result.x[:model.num_qsp_params]
        alphas = result.x[model.num_qsp_params:]

        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x_pruned, y_pruned

    else:
        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x, y

# -------------------------------
# Main execution
# -------------------------------
x_full = np.linspace(-1.2, 1.2, 200).reshape(-1, 1)
y_full = j0(20 * x_full)

model, preds_full, x_used, y_used = train_and_prune(
    x_full, y_full, width=[1, 1], steps=1000, pruning_threshold=0.05
)

# -------------------------------
# Plotting
# -------------------------------
plt.figure(figsize=(10, 6))
plt.plot(x_full, y_full, label="Target: J₀(20x)", linewidth=2)
plt.plot(x_used, preds_full, '--', label="KAN (after pruning)", linewidth=2)
plt.title("KAN QSP Bessel Approximation with Pruning")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
# Pruning: keeping 91 / 200 points

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.special import j0
from kan.KAN import KAN
from kan.qsp_activation import expectation_value

# -------------------------------
# Device setup
# -------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# -------------------------------
# Edge-warped sampling function
# -------------------------------
def warp_edges(L):
    t = np.linspace(0, np.pi, L)
    x_dense = np.cos(t)
    return np.sort(x_dense).reshape(-1, 1)

# -------------------------------
# Weighted cost function
# -------------------------------
def weighted_cost_fn(params, x, y_norm, depth, lambda_reg=1e-3):
    qsp_params = params[:2 * depth + 1]
    alphas = params[2 * depth + 1:]

    preds, weights = [], []
    for i in range(len(x)):
        theta = x[i][0]
        val = expectation_value(qsp_params, theta, depth=depth)
        preds.append(alphas[i] * val)
        weights.append(1 + 10 * (abs(theta) ** 2))

    preds = np.array(preds)
    weights = np.array(weights)
    mse = np.mean(weights * (y_norm.flatten() - preds) ** 2)
    alpha_penalty = lambda_reg * np.mean(np.square(alphas))
    return mse + alpha_penalty

# -------------------------------
# Train and optionally prune
# -------------------------------
def train_and_prune(x, y, width, qsp_depth=35, steps=1000, pruning_threshold=0.05):
    model = KAN(width, qsp_depth=qsp_depth, device=device)

    x_tensor = torch.tensor(x, dtype=torch.float32, device=device)
    y_tensor = torch.tensor(y, dtype=torch.float32, device=device)

    y_max = np.max(np.abs(y))
    y_norm = y / y_max

    init_qsp_params = np.linspace(0, np.pi, model.num_qsp_params)
    init_alphas = np.random.uniform(0.5, 1.5, x.shape[0])
    init_params = np.concatenate([init_qsp_params, init_alphas])

    result = model.fit_qsp_with_alphas(
        x_tensor, y_tensor,
        maxiter=steps,
        cost_fn=lambda p: weighted_cost_fn(p, x, y_norm, depth=qsp_depth),
        init_params=init_params
    )
    qsp_params = result.x[:model.num_qsp_params]
    alphas = result.x[model.num_qsp_params:]

    # -------------------------------
    # Pruning: keep samples with significant alpha × QSP(theta)
    # -------------------------------
    importance = np.abs([
        alphas[i] * expectation_value(qsp_params, x[i][0], depth=qsp_depth)
        for i in range(len(x))
    ])
    keep_indices = np.where(importance > pruning_threshold)[0]
    print(f"Pruning: keeping {len(keep_indices)} / {len(x)} points")

    # Retrain if pruning reduced the set
    if len(keep_indices) < len(x):
        x_pruned = x[keep_indices]
        y_pruned = y[keep_indices]
        model = KAN(width, qsp_depth=qsp_depth, device=device)
        x_tensor = torch.tensor(x_pruned, dtype=torch.float32, device=device)
        y_tensor = torch.tensor(y_pruned, dtype=torch.float32, device=device)

        result = model.fit_qsp_with_alphas(
            x_tensor, y_tensor,
            maxiter=steps,
            cost_fn=lambda p: weighted_cost_fn(p, x_pruned, y_pruned / y_max, qsp_depth),
            init_params=np.concatenate([qsp_params, alphas[keep_indices]])
        )
        qsp_params = result.x[:model.num_qsp_params]
        alphas = result.x[model.num_qsp_params:]

        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x_pruned, y_pruned

    else:
        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x, y

# -------------------------------
# Main execution
# -------------------------------
x_full = np.linspace(-1.2, 1.2, 200).reshape(-1, 1)
y_full = j0(20 * x_full)

model, preds_full, x_used, y_used = train_and_prune(
    x_full, y_full, width=[1, 1], steps=1000, pruning_threshold=0.05
)

# -------------------------------
# Plotting
# -------------------------------
plt.figure(figsize=(10, 6))
plt.plot(x_full, y_full, label="Target: J₀(20x)", linewidth=2)
plt.plot(x_used, preds_full, '--', label="KAN (after pruning)", linewidth=2)
plt.title("KAN QSP Bessel Approximation with Pruning")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
# Pruning: keeping 134 / 200 points

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.special import j0
from kan.KAN import KAN
from kan.qsp_activation import expectation_value

# -------------------------------
# Device setup
# -------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# -------------------------------
# Edge-warped sampling function
# -------------------------------
def warp_edges(L):
    t = np.linspace(0, np.pi, L)
    x_dense = np.cos(t)
    return np.sort(x_dense).reshape(-1, 1)

# -------------------------------
# Weighted cost function
# -------------------------------
def weighted_cost_fn(params, x, y_norm, depth, lambda_reg=1e-4):
    qsp_params = params[:2 * depth + 1]
    alphas = params[2 * depth + 1:]

    preds, weights = [], []
    for i in range(len(x)):
        theta = x[i][0]
        val = expectation_value(qsp_params, theta, depth=depth)
        preds.append(alphas[i] * val)
        weights.append(1 + 10 * (abs(theta) ** 2))

    preds = np.array(preds)
    weights = np.array(weights)
    mse = np.mean(weights * (y_norm.flatten() - preds) ** 2)
    alpha_penalty = lambda_reg * np.mean(np.square(alphas))
    return mse + alpha_penalty

# -------------------------------
# Train and optionally prune
# -------------------------------
def train_and_prune(x, y, width, qsp_depth=15, steps=1000, pruning_threshold=0.05):
    model = KAN(width, qsp_depth=qsp_depth, device=device)

    x_tensor = torch.tensor(x, dtype=torch.float32, device=device)
    y_tensor = torch.tensor(y, dtype=torch.float32, device=device)

    y_max = np.max(np.abs(y))
    y_norm = y / y_max

    init_qsp_params = np.linspace(0, np.pi, model.num_qsp_params)
    init_alphas = np.random.uniform(0.5, 1.5, x.shape[0])
    init_params = np.concatenate([init_qsp_params, init_alphas])

    result = model.fit_qsp_with_alphas(
        x_tensor, y_tensor,
        maxiter=steps,
        cost_fn=lambda p: weighted_cost_fn(p, x, y_norm, depth=qsp_depth),
        init_params=init_params
    )
    qsp_params = result.x[:model.num_qsp_params]
    alphas = result.x[model.num_qsp_params:]

    # -------------------------------
    # Pruning: keep samples with significant alpha × QSP(theta)
    # -------------------------------
    importance = np.abs([
        alphas[i] * expectation_value(qsp_params, x[i][0], depth=qsp_depth)
        for i in range(len(x))
    ])
    keep_indices = np.where(importance > pruning_threshold)[0]
    print(f"Pruning: keeping {len(keep_indices)} / {len(x)} points")

    # Retrain if pruning reduced the set
    if len(keep_indices) < len(x):
        x_pruned = x[keep_indices]
        y_pruned = y[keep_indices]
        model = KAN(width, qsp_depth=qsp_depth, device=device)
        x_tensor = torch.tensor(x_pruned, dtype=torch.float32, device=device)
        y_tensor = torch.tensor(y_pruned, dtype=torch.float32, device=device)

        result = model.fit_qsp_with_alphas(
            x_tensor, y_tensor,
            maxiter=steps,
            cost_fn=lambda p: weighted_cost_fn(p, x_pruned, y_pruned / y_max, qsp_depth),
            init_params=np.concatenate([qsp_params, alphas[keep_indices]])
        )
        qsp_params = result.x[:model.num_qsp_params]
        alphas = result.x[model.num_qsp_params:]

        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x_pruned, y_pruned

    else:
        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x, y

# -------------------------------
# Main execution
# -------------------------------
x_full = np.linspace(-1.2, 1.2, 200).reshape(-1, 1)
y_full = j0(20 * x_full)

model, preds_full, x_used, y_used = train_and_prune(
    x_full, y_full, width=[1, 10, 1], steps=1000, pruning_threshold=0.05
)

# -------------------------------
# Plotting
# -------------------------------
plt.figure(figsize=(10, 6))
plt.plot(x_full, y_full, label="Target: J₀(20x)", linewidth=2)
plt.plot(x_used, preds_full, '--', label="KAN (after pruning)", linewidth=2)
plt.title("KAN QSP Bessel Approximation with Pruning")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
# Pruning: keeping 98 / 200 points

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.special import j0
from kan.KAN import KAN
from kan.qsp_activation import expectation_value

# -------------------------------
# Device setup
# -------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# -------------------------------
# Edge-warped sampling (optional)
# -------------------------------
def warp_edges(L):
    t = np.linspace(0, np.pi, L)
    x_dense = np.cos(t)
    return np.sort(x_dense).reshape(-1, 1)

# -------------------------------
# Weighted cost function
# -------------------------------
def weighted_cost_fn(params, x, y_norm, depth, lambda_reg=1e-3):
    qsp_params = params[:2 * depth + 1]
    alphas = params[2 * depth + 1:]

    preds, weights = [], []
    for i in range(len(x)):
        theta = x[i][0]
        val = expectation_value(qsp_params, theta, depth=depth)
        preds.append(alphas[i] * val)
        weights.append(1 + 10 * (abs(theta) ** 2))

    preds = np.array(preds)
    weights = np.array(weights)
    mse = np.mean(weights * (y_norm.flatten() - preds) ** 2)
    alpha_penalty = lambda_reg * np.mean(np.square(alphas))
    return mse + alpha_penalty

# -------------------------------
# Train and prune a single region
# -------------------------------
def train_and_prune(x, y, width, qsp_depth=35, steps=1000, pruning_threshold=0.05, region_name=""):
    model = KAN(width, qsp_depth=qsp_depth, device=device)

    x_tensor = torch.tensor(x, dtype=torch.float32, device=device)
    y_tensor = torch.tensor(y, dtype=torch.float32, device=device)

    y_max = np.max(np.abs(y))
    y_norm = y / y_max

    init_qsp_params = np.linspace(0, np.pi, model.num_qsp_params)
    init_alphas = np.random.uniform(0.5, 1.5, x.shape[0])
    init_params = np.concatenate([init_qsp_params, init_alphas])

    result = model.fit_qsp_with_alphas(
        x_tensor, y_tensor,
        maxiter=steps,
        cost_fn=lambda p: weighted_cost_fn(p, x, y_norm, depth=qsp_depth),
        init_params=init_params
    )
    qsp_params = result.x[:model.num_qsp_params]
    alphas = result.x[model.num_qsp_params:]

    # -------------------------------
    # Prune based on importance
    # -------------------------------
    importance = np.abs([
        alphas[i] * expectation_value(qsp_params, x[i][0], depth=qsp_depth)
        for i in range(len(x))
    ])
    keep_indices = np.where(importance > pruning_threshold)[0]
    print(f"Pruning ({region_name}): keeping {len(keep_indices)} / {len(x)} points")

    # Retrain if pruning changed data
    if len(keep_indices) < len(x):
        x_pruned = x[keep_indices]
        y_pruned = y[keep_indices]
        model = KAN(width, qsp_depth=qsp_depth, device=device)
        x_tensor = torch.tensor(x_pruned, dtype=torch.float32, device=device)
        y_tensor = torch.tensor(y_pruned, dtype=torch.float32, device=device)

        result = model.fit_qsp_with_alphas(
            x_tensor, y_tensor,
            maxiter=steps,
            cost_fn=lambda p: weighted_cost_fn(p, x_pruned, y_pruned / y_max, qsp_depth),
            init_params=np.concatenate([qsp_params, alphas[keep_indices]])
        )
        qsp_params = result.x[:model.num_qsp_params]
        alphas = result.x[model.num_qsp_params:]

        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x_pruned, y_pruned

    else:
        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x, y

# -------------------------------
# Main execution — REGION LOOP
# -------------------------------
x_full = np.linspace(-1.2, 1.2, 200).reshape(-1, 1)
y_full = j0(20 * x_full)

regions = [(-1.2, -0.4), (-0.4, 0.4), (0.4, 1.2)]
all_preds = []
all_x = []
all_y = []

for idx, (a, b) in enumerate(regions):
    mask = (x_full[:, 0] >= a) & (x_full[:, 0] < b)
    x_region = x_full[mask]
    y_region = y_full[mask]

    print(f"\n=== Training Region {idx + 1}: x ∈ [{a}, {b}) ===")
    model, preds, x_used, y_used = train_and_prune(
        x_region, y_region,
        width=[1, 1],  # try [1, 10, 1] later
        steps=1000,
        pruning_threshold=0.05,
        qsp_depth=35,
        region_name=f"Region {idx+1}"
    )

    all_preds.append(preds)
    all_x.append(x_used)
    all_y.append(y_used)

# -------------------------------
# Final Plotting
# -------------------------------
plt.figure(figsize=(10, 6))
plt.plot(x_full, y_full, label="Target: J₀(20x)", linewidth=2)

for i in range(len(regions)):
    sort_idx = np.argsort(all_x[i].ravel())
    plt.plot(all_x[i][sort_idx], all_preds[i][sort_idx], '--', label=f"KAN (Region {i+1})", linewidth=2)

plt.title("KAN QSP Bessel Approximation by Region with Pruning")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
#
# === Training Region 1: x ∈ [-1.2, -0.4) ===
# Pruning (Region 1): keeping 62 / 67 points
#
# === Training Region 2: x ∈ [-0.4, 0.4) ===
# Pruning (Region 2): keeping 59 / 66 points
#
# === Training Region 3: x ∈ [0.4, 1.2) ===
# Pruning (Region 3): keeping 60 / 66 points

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.special import j0
from kan.KAN import KAN

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

x_full = np.linspace(-1.2, 1.2, 200).reshape(-1, 1)
y_full = j0(20 * x_full)

model = KAN(width=[1, 1], qsp_depth=35, device=device)
model.set_grid(x_full, num_regions=3)

x_tensor = torch.tensor(x_full, dtype=torch.float32, device=device)
y_tensor = torch.tensor(y_full, dtype=torch.float32, device=device)

print("Training grid-based QSP KAN...")
result = model.fit_grid_qsp_with_alphas(x_tensor, y_tensor, maxiter=1000)

# Extract trained parameters
num_qsp = model.num_qsp_params
qsp_param_sets = [result.x[i*num_qsp:(i+1)*num_qsp] for i in range(len(model.grid))]
alphas = result.x[len(model.grid)*num_qsp:]

# Evaluate predictions
with torch.no_grad():
    preds = model(x_tensor, qsp_param_sets, alphas).cpu().numpy()

plt.figure(figsize=(10, 6))
plt.plot(x_full, y_full, label="Target: J₀(20x)", linewidth=2)
plt.plot(x_full, preds, '--', label="KAN (Grid-Based)", linewidth=2)
plt.title("Grid-Based QSP-KAN Approximation of Bessel J₀(20x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
# Training grid-based QSP KAN...

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.special import j0
from kan.KAN import KAN
from kan.qsp_activation import expectation_value

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

def weighted_cost_fn(params, x, y_norm, depth, lambda_reg=1e-4):
    qsp_params = params[:2 * depth + 1]
    alphas = params[2 * depth + 1:]

    preds, weights = [], []
    for i in range(len(x)):
        theta = x[i][0]
        val = expectation_value(qsp_params, theta, depth=depth)
        preds.append(alphas[i] * val)
        weights.append(1 + 10 * (abs(theta) ** 2))

    preds = np.array(preds)
    weights = np.array(weights)
    mse = np.mean(weights * (y_norm.flatten() - preds) ** 2)
    alpha_penalty = lambda_reg * np.mean(np.square(alphas))
    return mse + alpha_penalty

def train_and_prune(x, y, width, qsp_depth=15, steps=1000, pruning_threshold=0.05):
    model = KAN(width, qsp_depth=qsp_depth, device=device)

    x_tensor = torch.tensor(x, dtype=torch.float32, device=device)
    y_tensor = torch.tensor(y, dtype=torch.float32, device=device)

    y_max = np.max(np.abs(y))
    y_norm = y / y_max

    init_qsp_params = np.linspace(0, np.pi, model.num_qsp_params)
    init_alphas = np.random.uniform(0.5, 1.5, x.shape[0])
    init_params = np.concatenate([init_qsp_params, init_alphas])

    result = model.fit_qsp_with_alphas(
        x_tensor, y_tensor,
        maxiter=steps,
        cost_fn=lambda p: weighted_cost_fn(p, x, y_norm, depth=qsp_depth),
        init_params=init_params
    )
    qsp_params = result.x[:model.num_qsp_params]
    alphas = result.x[model.num_qsp_params:]

    importance = np.abs([
        alphas[i] * expectation_value(qsp_params, x[i][0], depth=qsp_depth)
        for i in range(len(x))
    ])
    keep_indices = np.where(importance > pruning_threshold)[0]
    print(f"Pruning: keeping {len(keep_indices)} / {len(x)} points")

    if len(keep_indices) < len(x):
        x_pruned = x[keep_indices]
        y_pruned = y[keep_indices]
        model = KAN(width, qsp_depth=qsp_depth, device=device)
        x_tensor = torch.tensor(x_pruned, dtype=torch.float32, device=device)
        y_tensor = torch.tensor(y_pruned, dtype=torch.float32, device=device)

        result = model.fit_qsp_with_alphas(
            x_tensor, y_tensor,
            maxiter=steps,
            cost_fn=lambda p: weighted_cost_fn(p, x_pruned, y_pruned / y_max, qsp_depth),
            init_params=np.concatenate([qsp_params, alphas[keep_indices]])
        )
        qsp_params = result.x[:model.num_qsp_params]
        alphas = result.x[model.num_qsp_params:]

        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x_pruned, y_pruned

    else:
        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x, y

x_full = np.linspace(-1.2, 1.2, 200).reshape(-1, 1)
y_full = j0(20 * x_full)

model, preds_full, x_used, y_used = train_and_prune(
    x_full, y_full, width=[1, 10, 1], steps=1000, pruning_threshold=0.05
)

plt.figure(figsize=(10, 6))
plt.plot(x_full, y_full, label="Target: J₀(20x)", linewidth=2)
plt.plot(x_used, preds_full, '--', label="KAN (after pruning)", linewidth=2)
plt.title("KAN QSP Bessel Approximation with Global Pruning")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
# Pruning: keeping 123 / 200 points

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.special import j0
from kan.KAN import KAN
from kan.qsp_activation import expectation_value

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

def weighted_cost_fn(params, x, y_norm, depth, lambda_reg=1e-4):
    qsp_params = params[:2 * depth + 1]
    alphas = params[2 * depth + 1:]

    preds, weights = [], []
    for i in range(len(x)):
        theta = x[i][0]
        val = expectation_value(qsp_params, theta, depth=depth)
        preds.append(alphas[i] * val)
        weights.append(1 + 10 * (abs(theta) ** 2))

    preds = np.array(preds)
    weights = np.array(weights)
    mse = np.mean(weights * (y_norm.flatten() - preds) ** 2)
    alpha_penalty = lambda_reg * np.mean(np.square(alphas))
    return mse + alpha_penalty

def train_and_prune(x, y, width, qsp_depth=35, steps=1000, pruning_threshold=0.05):
    model = KAN(width, qsp_depth=qsp_depth, device=device)

    x_tensor = torch.tensor(x, dtype=torch.float32, device=device)
    y_tensor = torch.tensor(y, dtype=torch.float32, device=device)

    y_max = np.max(np.abs(y))
    y_norm = y / y_max

    init_qsp_params = np.linspace(0, np.pi, model.num_qsp_params)
    init_alphas = np.random.uniform(0.5, 1.5, x.shape[0])
    init_params = np.concatenate([init_qsp_params, init_alphas])

    result = model.fit_qsp_with_alphas(
        x_tensor, y_tensor,
        maxiter=steps,
        cost_fn=lambda p: weighted_cost_fn(p, x, y_norm, depth=qsp_depth),
        init_params=init_params
    )
    qsp_params = result.x[:model.num_qsp_params]
    alphas = result.x[model.num_qsp_params:]

    importance = np.abs([
        alphas[i] * expectation_value(qsp_params, x[i][0], depth=qsp_depth)
        for i in range(len(x))
    ])
    keep_indices = np.where(importance > pruning_threshold)[0]
    print(f"Pruning: keeping {len(keep_indices)} / {len(x)} points")

    if len(keep_indices) < len(x):
        x_pruned = x[keep_indices]
        y_pruned = y[keep_indices]
        model = KAN(width, qsp_depth=qsp_depth, device=device)
        x_tensor = torch.tensor(x_pruned, dtype=torch.float32, device=device)
        y_tensor = torch.tensor(y_pruned, dtype=torch.float32, device=device)

        result = model.fit_qsp_with_alphas(
            x_tensor, y_tensor,
            maxiter=steps,
            cost_fn=lambda p: weighted_cost_fn(p, x_pruned, y_pruned / y_max, qsp_depth),
            init_params=np.concatenate([qsp_params, alphas[keep_indices]])
        )
        qsp_params = result.x[:model.num_qsp_params]
        alphas = result.x[model.num_qsp_params:]

        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x_pruned, y_pruned

    else:
        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x, y

x_full = np.linspace(-1.2, 1.2, 200).reshape(-1, 1)
y_full = j0(20 * x_full)

model, preds_full, x_used, y_used = train_and_prune(
    x_full, y_full, width=[1, 10, 1], steps=1000, pruning_threshold=0.05
)

plt.figure(figsize=(10, 6))
plt.plot(x_full, y_full, label="Target: J₀(20x)", linewidth=2)
plt.plot(x_used, preds_full, '--', label="KAN (after pruning)", linewidth=2)
plt.title("KAN QSP Bessel Approximation with Global Pruning")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
# Pruning: keeping 132 / 200 points

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.special import j0
from kan.KAN import KAN
from kan.qsp_activation import expectation_value

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

def weighted_cost_fn(params, x, y_norm, depth, lambda_reg=1e-4):
    qsp_params = params[:2 * depth + 1]
    alphas = params[2 * depth + 1:]

    preds, weights = [], []
    for i in range(len(x)):
        theta = x[i][0]
        val = expectation_value(qsp_params, theta, depth=depth)
        preds.append(alphas[i] * val)
        weights.append(1 + 10 * (abs(theta) ** 2))

    preds = np.array(preds)
    weights = np.array(weights)
    mse = np.mean(weights * (y_norm.flatten() - preds) ** 2)
    alpha_penalty = lambda_reg * np.mean(np.square(alphas))
    return mse + alpha_penalty

def train_and_prune(x, y, width, qsp_depth=25, steps=1000, pruning_threshold=0.05):
    model = KAN(width, qsp_depth=qsp_depth, device=device)

    x_tensor = torch.tensor(x, dtype=torch.float32, device=device)
    y_tensor = torch.tensor(y, dtype=torch.float32, device=device)

    y_max = np.max(np.abs(y))
    y_norm = y / y_max

    init_qsp_params = np.linspace(0, np.pi, model.num_qsp_params)
    init_alphas = np.random.uniform(0.5, 1.5, x.shape[0])
    init_params = np.concatenate([init_qsp_params, init_alphas])

    result = model.fit_qsp_with_alphas(
        x_tensor, y_tensor,
        maxiter=steps,
        cost_fn=lambda p: weighted_cost_fn(p, x, y_norm, depth=qsp_depth),
        init_params=init_params
    )
    qsp_params = result.x[:model.num_qsp_params]
    alphas = result.x[model.num_qsp_params:]

    importance = np.abs([
        alphas[i] * expectation_value(qsp_params, x[i][0], depth=qsp_depth)
        for i in range(len(x))
    ])
    keep_indices = np.where(importance > pruning_threshold)[0]
    print(f"Pruning: keeping {len(keep_indices)} / {len(x)} points")

    if len(keep_indices) < len(x):
        x_pruned = x[keep_indices]
        y_pruned = y[keep_indices]
        model = KAN(width, qsp_depth=qsp_depth, device=device)
        x_tensor = torch.tensor(x_pruned, dtype=torch.float32, device=device)
        y_tensor = torch.tensor(y_pruned, dtype=torch.float32, device=device)

        result = model.fit_qsp_with_alphas(
            x_tensor, y_tensor,
            maxiter=steps,
            cost_fn=lambda p: weighted_cost_fn(p, x_pruned, y_pruned / y_max, qsp_depth),
            init_params=np.concatenate([qsp_params, alphas[keep_indices]])
        )
        qsp_params = result.x[:model.num_qsp_params]
        alphas = result.x[model.num_qsp_params:]

        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x_pruned, y_pruned

    else:
        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x, y

x_full = np.linspace(-1.2, 1.2, 200).reshape(-1, 1)
y_full = j0(20 * x_full)

model, preds_full, x_used, y_used = train_and_prune(
    x_full, y_full, width=[1, 10, 1], steps=1000, pruning_threshold=0.05
)

plt.figure(figsize=(10, 6))
plt.plot(x_full, y_full, label="Target: J₀(20x)", linewidth=2)
plt.plot(x_used, preds_full, '--', label="KAN (after pruning)", linewidth=2)
plt.title("KAN QSP Bessel Approximation with Global Pruning")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.special import j0
from kan.KAN import KAN
from kan.qsp_activation import expectation_value

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

def weighted_cost_fn(params, x, y_norm, depth, lambda_reg=1e-4):
    qsp_params = params[:2 * depth + 1]
    alphas = params[2 * depth + 1:]

    preds, weights = [], []
    for i in range(len(x)):
        theta = x[i][0]
        val = expectation_value(qsp_params, theta, depth=depth)
        preds.append(alphas[i] * val)
        weights.append(1 + 10 * (abs(theta) ** 2))

    preds = np.array(preds)
    weights = np.array(weights)
    mse = np.mean(weights * (y_norm.flatten() - preds) ** 2)
    alpha_penalty = lambda_reg * np.mean(np.square(alphas))
    return mse + alpha_penalty

def train_and_prune(x, y, width, qsp_depth=30, steps=1000, pruning_threshold=0.03):
    model = KAN(width, qsp_depth=qsp_depth, device=device)

    x_tensor = torch.tensor(x, dtype=torch.float32, device=device)
    y_tensor = torch.tensor(y, dtype=torch.float32, device=device)

    y_max = np.max(np.abs(y))
    y_norm = y / y_max

    init_qsp_params = np.linspace(0, np.pi, model.num_qsp_params)
    init_alphas = np.random.uniform(0.5, 1.5, x.shape[0])
    init_params = np.concatenate([init_qsp_params, init_alphas])

    result = model.fit_qsp_with_alphas(
        x_tensor, y_tensor,
        maxiter=steps,
        cost_fn=lambda p: weighted_cost_fn(p, x, y_norm, depth=qsp_depth),
        init_params=init_params
    )
    qsp_params = result.x[:model.num_qsp_params]
    alphas = result.x[model.num_qsp_params:]

    importance = np.abs([
        alphas[i] * expectation_value(qsp_params, x[i][0], depth=qsp_depth)
        for i in range(len(x))
    ])
    keep_indices = np.where(importance > pruning_threshold)[0]
    print(f"Pruning: keeping {len(keep_indices)} / {len(x)} points")

    if len(keep_indices) < len(x):
        x_pruned = x[keep_indices]
        y_pruned = y[keep_indices]
        model = KAN(width, qsp_depth=qsp_depth, device=device)
        x_tensor = torch.tensor(x_pruned, dtype=torch.float32, device=device)
        y_tensor = torch.tensor(y_pruned, dtype=torch.float32, device=device)

        result = model.fit_qsp_with_alphas(
            x_tensor, y_tensor,
            maxiter=steps,
            cost_fn=lambda p: weighted_cost_fn(p, x_pruned, y_pruned / y_max, qsp_depth),
            init_params=np.concatenate([qsp_params, alphas[keep_indices]])
        )
        qsp_params = result.x[:model.num_qsp_params]
        alphas = result.x[model.num_qsp_params:]

        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x_pruned, y_pruned

    else:
        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x, y

x_full = np.linspace(-1.2, 1.2, 200).reshape(-1, 1)
y_full = j0(20 * x_full)

model, preds_full, x_used, y_used = train_and_prune(
    x_full, y_full, width=[1, 10, 1], steps=1000, pruning_threshold=0.03
)

plt.figure(figsize=(10, 6))
plt.plot(x_full, y_full, label="Target: J₀(20x)", linewidth=2)
plt.plot(x_used, preds_full, '--', label="KAN (after pruning)", linewidth=2)
plt.title("KAN QSP Bessel Approximation with Global Pruning")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
# Pruning: keeping 149 / 200 points

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.special import j0
from kan.KAN import KAN
from kan.qsp_activation import expectation_value

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

def weighted_cost_fn(params, x, y_norm, depth, lambda_reg=1e-4):
    qsp_params = params[:2 * depth + 1]
    alphas = params[2 * depth + 1:]

    preds, weights = [], []
    for i in range(len(x)):
        theta = x[i][0]
        val = expectation_value(qsp_params, theta, depth=depth)
        preds.append(alphas[i] * val)
        weights.append(1 + 40 * np.sin(np.pi * abs(theta)) ** 2)

    preds = np.array(preds)
    weights = np.array(weights)
    mse = np.mean(weights * (y_norm.flatten() - preds) ** 2)
    alpha_penalty = lambda_reg * np.mean(np.square(alphas))
    return mse + alpha_penalty

def train_and_prune(x, y, width, qsp_depth=25, steps=1000, pruning_threshold=0.05):
    model = KAN(width, qsp_depth=qsp_depth, device=device)

    x_tensor = torch.tensor(x, dtype=torch.float32, device=device)
    y_tensor = torch.tensor(y, dtype=torch.float32, device=device)

    y_max = np.max(np.abs(y))
    y_norm = y / y_max

    init_qsp_params = np.linspace(0, np.pi, model.num_qsp_params)
    init_alphas = np.random.uniform(0.5, 1.5, x.shape[0])
    init_params = np.concatenate([init_qsp_params, init_alphas])

    result = model.fit_qsp_with_alphas(
        x_tensor, y_tensor,
        maxiter=steps,
        cost_fn=lambda p: weighted_cost_fn(p, x, y_norm, depth=qsp_depth),
        init_params=init_params
    )
    qsp_params = result.x[:model.num_qsp_params]
    alphas = result.x[model.num_qsp_params:]

    importance = np.abs([
        alphas[i] * expectation_value(qsp_params, x[i][0], depth=qsp_depth)
        for i in range(len(x))
    ])
    keep_indices = np.where(importance > pruning_threshold)[0]
    print(f"Pruning: keeping {len(keep_indices)} / {len(x)} points")

    if len(keep_indices) < len(x):
        x_pruned = x[keep_indices]
        y_pruned = y[keep_indices]
        model = KAN(width, qsp_depth=qsp_depth, device=device)
        x_tensor = torch.tensor(x_pruned, dtype=torch.float32, device=device)
        y_tensor = torch.tensor(y_pruned, dtype=torch.float32, device=device)

        result = model.fit_qsp_with_alphas(
            x_tensor, y_tensor,
            maxiter=steps,
            cost_fn=lambda p: weighted_cost_fn(p, x_pruned, y_pruned / y_max, qsp_depth),
            init_params=np.concatenate([qsp_params, alphas[keep_indices]])
        )
        qsp_params = result.x[:model.num_qsp_params]
        alphas = result.x[model.num_qsp_params:]

        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x_pruned, y_pruned

    else:
        preds = model(x_tensor, qsp_params, alphas).detach().cpu().numpy()
        preds = preds * y_max
        return model, preds, x, y

x_full = np.linspace(-1.2, 1.2, 200).reshape(-1, 1)
y_full = j0(20 * x_full)

model, preds_full, x_used, y_used = train_and_prune(
    x_full, y_full, width=[1, 10, 1], steps=1000, pruning_threshold=0.01
)

plt.figure(figsize=(10, 6))
plt.plot(x_full, y_full, label="Target: J₀(20x)", linewidth=2)
plt.plot(x_used, preds_full, '--', label="KAN (after pruning)", linewidth=2)
plt.title("KAN QSP Bessel Approximation with Global Pruning")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
# Pruning: keeping 189 / 200 points

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.special import j0
from kan.KAN import KAN
from kan.qsp_activation import expectation_value

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# Generate input data
x_full = np.linspace(-1.2, 1.2, 200).reshape(-1, 1)
y_full = j0(20 * x_full)
y_max = np.max(np.abs(y_full))
y_norm = y_full / y_max

x_tensor = torch.tensor(x_full, dtype=torch.float32, device=device)
y_tensor = torch.tensor(y_norm, dtype=torch.float32, device=device)

# Build and train model
model = KAN(width=[1, 10, 1], qsp_depth=25, device=device)

print("Fitting model...")
result = model.fit_qsp_with_alphas(x_tensor, y_tensor, maxiter=1000)

qsp_params = result.x[:model.num_qsp_params]
alphas = result.x[model.num_qsp_params:-1]
bias = result.x[-1]

# Pruning phase
importance = np.abs([
    alphas[i] * expectation_value(qsp_params, x_full[i][0], depth=model.qsp_depth) + bias
    for i in range(len(x_full))
])
threshold = 0.05
keep_indices = np.where(importance > threshold)[0]
print(f"Pruning: keeping {len(keep_indices)} / {len(x_full)} points")

x_pruned = x_full[keep_indices]
y_pruned = y_full[keep_indices]
x_tensor_pruned = torch.tensor(x_pruned, dtype=torch.float32, device=device)
y_tensor_pruned = torch.tensor(y_pruned / y_max, dtype=torch.float32, device=device)

# Retrain after pruning
model = KAN(width=[1, 10, 1], qsp_depth=25, device=device)
print("Refitting after pruning...")
result = model.fit_qsp_with_alphas(x_tensor_pruned, y_tensor_pruned, maxiter=1000)

qsp_params = result.x[:model.num_qsp_params]
alphas = result.x[model.num_qsp_params:-1]
bias = result.x[-1]

# Final prediction
with torch.no_grad():
    preds = model(x_tensor_pruned, qsp_params, alphas, bias=bias).cpu().numpy()
    preds = preds * y_max

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(x_full, y_full, label="Target: J₀(20x)", linewidth=2)
plt.plot(x_pruned, preds, '--', label="KAN (after pruning)", linewidth=2)
plt.title("KAN QSP Bessel Approximation with Global Pruning")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Device: cuda
# Fitting model...
# Pruning: keeping 176 / 200 points
# Refitting after pruning...

# %%
########################### THIS ONE IS WORSE THAN 25

import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.special import j0
from kan.KAN import KAN
from kan.qsp_activation import expectation_value

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# Generate input data
x_full = np.linspace(-1.2, 1.2, 200).reshape(-1, 1)
y_full = j0(20 * x_full)
y_max = np.max(np.abs(y_full))
y_norm = y_full / y_max

x_tensor = torch.tensor(x_full, dtype=torch.float32, device=device)
y_tensor = torch.tensor(y_norm, dtype=torch.float32, device=device)

# Build and train model
model = KAN(width=[1, 10, 1], qsp_depth=30, device=device)

print("Fitting model...")
result = model.fit_qsp_with_alphas(x_tensor, y_tensor, maxiter=1000)

qsp_params = result.x[:model.num_qsp_params]
alphas = result.x[model.num_qsp_params:-1]
bias = result.x[-1]

# Pruning phase
importance = np.abs([
    alphas[i] * expectation_value(qsp_params, x_full[i][0], depth=model.qsp_depth) + bias
    for i in range(len(x_full))
])
threshold = 0.05
keep_indices = np.where(importance > threshold)[0]
print(f"Pruning: keeping {len(keep_indices)} / {len(x_full)} points")

x_pruned = x_full[keep_indices]
y_pruned = y_full[keep_indices]
x_tensor_pruned = torch.tensor(x_pruned, dtype=torch.float32, device=device)
y_tensor_pruned = torch.tensor(y_pruned / y_max, dtype=torch.float32, device=device)

# Retrain after pruning
model = KAN(width=[1, 10, 1], qsp_depth=30, device=device)
print("Refitting after pruning...")
result = model.fit_qsp_with_alphas(x_tensor_pruned, y_tensor_pruned, maxiter=1000)

qsp_params = result.x[:model.num_qsp_params]
alphas = result.x[model.num_qsp_params:-1]
bias = result.x[-1]

# Final prediction
with torch.no_grad():
    preds = model(x_tensor_pruned, qsp_params, alphas, bias=bias).cpu().numpy()
    preds = preds * y_max

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(x_full, y_full, label="Target: J₀(20x)", linewidth=2)
plt.plot(x_pruned, preds, '--', label="KAN (after pruning)", linewidth=2)
plt.title("KAN QSP Bessel Approximation with Global Pruning")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Device: cuda
# Fitting model...
# Pruning: keeping 174 / 200 points
# Refitting after pruning...

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.special import j0
from kan.KAN import KAN
from kan.qsp_activation import expectation_value

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

x_full = np.linspace(-1.2, 1.2, 200).reshape(-1, 1)
y_full = j0(20 * x_full)
y_max = np.max(np.abs(y_full))
y_norm = y_full / y_max

x_tensor = torch.tensor(x_full, dtype=torch.float32, device=device)
y_tensor = torch.tensor(y_norm, dtype=torch.float32, device=device)

model = KAN(width=[1, 10, 1], qsp_depth=27, device=device)

print("Fitting model...")
result = model.fit_qsp_with_alphas(x_tensor, y_tensor, maxiter=1000)

qsp_params = result.x[:model.num_qsp_params]
alphas = result.x[model.num_qsp_params:-1]
bias = result.x[-1]

# Internal pruning
print("Pruning internal KAN weights...")
model.prune_internal_nodes(threshold=0.05)

with torch.no_grad():
    preds = model(x_tensor, qsp_params, alphas, bias=bias).cpu().numpy() * y_max

plt.figure(figsize=(10, 6))
plt.plot(x_full, y_full, label="Target: J₀(20x)", linewidth=2)
plt.plot(x_full, preds, '--', label="KAN (after internal pruning)", linewidth=2)
plt.title("KAN QSP Bessel Approximation with Node Pruning")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Device: cuda
# Fitting model...
# Pruning internal KAN weights...

# %%
# Error Plot: Pointwise Absolute Error
errors = np.abs(preds - y_full)

plt.figure(figsize=(10, 6))
plt.plot(x_full, errors, color='crimson', linewidth=2)
plt.title("Pointwise Absolute Error |KAN(x) - J₀(20x)| after Node Pruning")
plt.xlabel("x")
plt.ylabel("Absolute Error")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from scipy.special import j0
from kan.KAN import KAN
from kan.qsp_activation import expectation_value
from mpl_toolkits.mplot3d import Axes3D

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# Generate meshgrid data for f(x, y) = xy
grid_res = 20  # adjust for smoother plot
x1_vals = np.linspace(-1, 1, grid_res)
x2_vals = np.linspace(-1, 1, grid_res)
x1, x2 = np.meshgrid(x1_vals, x2_vals)

x_full = np.stack([x1.ravel(), x2.ravel()], axis=1)  # shape (N, 2)
y_full = (x_full[:, 0] * x_full[:, 1]).reshape(-1, 1)  # target: f(x, y) = xy
y_max = np.max(np.abs(y_full))
y_norm = y_full / y_max

x_tensor = torch.tensor(x_full, dtype=torch.float32, device=device)
y_tensor = torch.tensor(y_norm, dtype=torch.float32, device=device)

# Build and train the model
model = KAN(width=[2, 10, 10, 1], qsp_depth=27, device=device)
print("Fitting model...")
result = model.fit_qsp_with_alphas(x_tensor, y_tensor, maxiter=1000)

qsp_params = result.x[:model.num_qsp_params]
alphas = result.x[model.num_qsp_params:-1]
bias = result.x[-1]

# Internal pruning
print("Pruning internal KAN weights...")
model.prune_internal_nodes(threshold=0.05)

# Predict
with torch.no_grad():
    preds = model(x_tensor, qsp_params, alphas, bias=bias).cpu().numpy() * y_max

# Reshape for 3D plotting
x1 = x_full[:, 0].reshape(grid_res, grid_res)
x2 = x_full[:, 1].reshape(grid_res, grid_res)
y_true = y_full.reshape(grid_res, grid_res)
y_pred = preds.reshape(grid_res, grid_res)

# Plot true and predicted surface
fig = plt.figure(figsize=(14, 6))

# True surface
ax1 = fig.add_subplot(1, 2, 1, projection='3d')
ax1.plot_surface(x1, x2, y_true, cmap='viridis', edgecolor='k', linewidth=0.3, alpha=0.9)
ax1.set_title("True Surface: f(x, y) = xy")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax1.set_zlabel("f(x, y)")

# KAN predicted surface
ax2 = fig.add_subplot(1, 2, 2, projection='3d')
ax2.plot_surface(x1, x2, y_pred, cmap='plasma', edgecolor='k', linewidth=0.3, alpha=0.9)
ax2.set_title("KAN Prediction")
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax2.set_zlabel("f(x, y)")

plt.tight_layout()
plt.show()
# Out:
# Device: cuda
# Fitting model...
# Pruning internal KAN weights...

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from scipy.special import j0
from kan.KAN import KAN
from kan.qsp_activation import expectation_value
from mpl_toolkits.mplot3d import Axes3D

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# Generate meshgrid data for f(x, y) = xy
grid_res = 20  # adjust for smoother plot
x1_vals = np.linspace(-1, 1, grid_res)
x2_vals = np.linspace(-1, 1, grid_res)
x1, x2 = np.meshgrid(x1_vals, x2_vals)

x_full = np.stack([x1.ravel(), x2.ravel()], axis=1)  # shape (N, 2)
y_full = (x_full[:, 0] * x_full[:, 1]).reshape(-1, 1)  # target: f(x, y) = xy
y_max = np.max(np.abs(y_full))
y_norm = y_full / y_max

x_tensor = torch.tensor(x_full, dtype=torch.float32, device=device)
y_tensor = torch.tensor(y_norm, dtype=torch.float32, device=device)

# Build and train the model
model = KAN(width=[2, 2, 1], qsp_depth=27, device=device)
print("Fitting model...")
result = model.fit_qsp_with_alphas(x_tensor, y_tensor, maxiter=1000)

qsp_params = result.x[:model.num_qsp_params]
alphas = result.x[model.num_qsp_params:-1]
bias = result.x[-1]

# Internal pruning
print("Pruning internal KAN weights...")
model.prune_internal_nodes(threshold=0.05)

# Predict
with torch.no_grad():
    preds = model(x_tensor, qsp_params, alphas, bias=bias).cpu().numpy() * y_max

# Reshape for 3D plotting
x1 = x_full[:, 0].reshape(grid_res, grid_res)
x2 = x_full[:, 1].reshape(grid_res, grid_res)
y_true = y_full.reshape(grid_res, grid_res)
y_pred = preds.reshape(grid_res, grid_res)

# Plot true and predicted surface
fig = plt.figure(figsize=(14, 6))

# True surface
ax1 = fig.add_subplot(1, 2, 1, projection='3d')
ax1.plot_surface(x1, x2, y_true, cmap='viridis', edgecolor='k', linewidth=0.3, alpha=0.9)
ax1.set_title("True Surface: f(x, y) = xy")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax1.set_zlabel("f(x, y)")

# KAN predicted surface
ax2 = fig.add_subplot(1, 2, 2, projection='3d')
ax2.plot_surface(x1, x2, y_pred, cmap='plasma', edgecolor='k', linewidth=0.3, alpha=0.9)
ax2.set_title("KAN Prediction")
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax2.set_zlabel("f(x, y)")

plt.tight_layout()
plt.show()
